# %% [markdown]
# SENG265 Term Project
#
# Menoa Brennan
# V01000267
#
# Part 1:
#
# (question 1) What is the core functionality of Jupyter notebooks?
# after doing some research on jupyter notbooks I have found out tha the core functionality is the fact that you can code,
# print the output and explain what you have done all in one place. jupyter makes it easy to ducument your code and explain
# it to others.
#
# (question 2) Summarize simple Jupyter notebook markdown including how to insert links and images?
# When it comes to the markdown it gives what is in the cell almost a typing just like in programming (i.e int char float..) fro instance if I were to write some code that i dont wan to run, i would just convert it into markdown so that it isnt seen as code. When is comes to inserting links, you can make them look good by formatting them with code at first and then converiting it into markdown. I just use the edit bar and click insert image so that it formats it all for me.
# heres an examples:

# %% [markdown]
# ![Linuximage.jpg](attachment:Linuximage.jpg)

# %% [markdown]
# This code will output this image above (must be in markdown I found out)

# %% [markdown]
# ![Linuximage.jpg](attachment:Linuximage.jpg) When it comes to links its far more straight forward, for simple links anyways.

# %% [markdown]
# https://www.linkedin.com/

# %% [markdown]
# or you can name it so that it wont be just the web browser link

# %% [markdown]
# [Linkedin link](https://www.linkedin.com/)

# %% [markdown]
# (question 3) How can you typeset mathematical formulas including Greek letters using LaTeX Markdown in Jupyter Notebooks?
# When it comes to mathematical greek letters there from what i have just learned you need to put your formula in between $'equation'$

# %% [markdown]
# $e=mc^2$

# %% [markdown]
# $\frac{x}{y}$

# %% [markdown]
# these would be $e=mc^2$ and $\frac{x}{y}$. When it comes to greek letters theres unique syntax for different things.

# %% [markdown]
# /sigma /delta /alpha or whatever greek letter you want

# %% [markdown]
# (question 4) What is the history of Unix or Linux? How prevalent is Unix or Linux in software development today?
# Just being breif from what is in the slides. Developers at Bell Laboratories, Ken Thompson and Dennis Ritchie, developed Unix in the late 1960s. It was created as an easy-to-use operating system for minicomputers, and in the 1970s and 1980s, its use skyrocketed. Linus Torvalds developed Linux, an open-source operating system based on Unix, at the beginning of the 1990s. Linux quickly became well-liked among developers, in part because of its adaptability, dependability, and cost. Currently, Linux and Unix are widely utilised in the software development industry, especially in the fields of scientific computing, cloud computing, and web development. Because of their dependability, security, and usability, Unix and Linux are preferred by many developers above other operating systems. In addition, a lot of databases, web servers, and other software. online it even says that between 66% to 75% of Internet servers are running UNIX or Linux. This just shows how important it is today.
#
# (question 5) What is the core functionality of the Bash command and scripting language?
# After doing research on bash, I would describe it as a powerful and flexible tool that is essential for anyone working with Unix-based operating systems. Bash provides a comprehensive set of functionalities for working with the command-line interface, executing commands, and writing scripts. One of the most significant advantages of Bash is its flexibility. It can be used to automate a wide range of tasks, from simple file management to more complex system administration tasks. Additionally, Bash scripts can be customized to meet the specific needs of different users, making it an incredibly versatil tool. In my research, I found that Bash is widely used in modern software development, particularly in areas such as web development, cloud computing, and scientific computing. Its ability to interact with the operating system and execute complex commands make it an essential tool for developers who need to manage complex systems and automate repetitive tasks. Overall, I would strongly recommend that anyone working with Unix-based operating systems take the time to learn Bash. Its power and flexibility make it an incredibly valuable tool, and it's an essential part of any software engineer's toolkit.
#
# (question 6) Why is version control and configuration management critical in software development projects?
# As a software engineering student, I understand that version control and configuration management are critical components of software development projects. Version control allows developers to track changes to code over time and collaborate on code changes effectively. This enable multiple developers to work on the same codebase without conflicting changes. Additionally, version control makes it easier to identify and fix bugs and roll back to previous versions if needed. Configuration management is also critical in software development projects. It involves managig the configuration and settings of software systems and ensuring consistency across different environments. Configuration management helps ensure that software runs correctly on different platforms and reduces the risk of errors and inconsistencies. By using version control and configuration management tools, software engineers can work more efficiently, reduce errors, and improve the quality of software products.
#
# (question 7) What are the core functionalities of Git, Github, and Gitlab?
#
#
# (question 8) What is your background in the programming language C? How prevalent is C in software development today?
# Right now I have no experience in programming with C. I took my first year of engineering at the university of alberta. This meant that before comeing to uvic for my second year of engineering my only background with codibg was matlab. At uvic my first non reaseach language coding course was csc115 which was completely in java. Since C was generally the first high level programming language, C is extremely prevalent in modern day sofware development. C is considered to be "the mother of all languages" meaning all modern day languages have certain portions of C. I attatched a video a found interesting below.

# %%
from IPython.display import YouTubeVideo

# %%
video = YouTubeVideo("https://www.youtube.com/watch?v=_L86DO3tkTQ")

# %%
display(video)
# Out:
#         <iframe
#             width="400"
#             height="300"
#             src="https://www.youtube.com/embed/https://www.youtube.com/watch?v=_L86DO3tkTQ"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# (question 9) What is your background in the programming language Python 3? How prevalent is Python 3 in software development today?
# I touched on python recently after I joined the Uvic AI club whe I was trying to create my own battle snake. Otherwise I have only heard other people talk about it. Since im looking to go into machine learning and artificial intellingence, In the future I will be taking a deep dive into python as it it the most prevalent language for machine learning. Since python is such an user friendly laguage I feel as though it is very prevalent in software development. According to the TIOBE Index, which tracks the popularity of programming languages, Python has been steadily increasing in popularity for several years and is currently the third most popular programming language in the world. Python's popularity can be attributed to its ease of use, versatility, and extensive libraries and frameworks that allow developers to build complex applications quickly. Many large organizations, including Google, Dropbox, and Instagram, have adopted Python as their primary programming language for various applications and projects. Needless to say that it is an extremely prevalent laguage.

# %%
def my_function():
    print('hello world')
    
    
my_function()
# Out:
# hello world

# %% [markdown]
# (question 11) How is Git used as a version control system?
# I've discovered how important Git is to software development projects. Git is a distributed version control system that enables programmers to efficiently cooperate with one another and track changes to their code. It's a crucial tool for maintaining the source code and project versions throughout time. The primary functions of Git include repository creation, branching, committing, and merging changes. Once they are happy with their work, developers utilise Git to build a new repository and then commit it. Each commit includes a special identification that may be used to access it later. Commits are similar to snapshots of the codebase taken at specific points in time. We have been usingthe in our labs and I am starting to see how it is used as a control system first hand. The only problem is there isnt any assignments that are team based so i havent really been able to use some of the core functionalities. This is what ive used mainly when it comes to submitting my labs and assignment 1.

# %%
git add route_manager.c

# %%
git commit -m "comment"

# %%
git push

# %% [markdown]
# (question 12) How can Git be used effectively in a highly distributed software development environment involving multiple countries?
# I found that Git is a suitable version control system for software development in a highly distributed environment with multiple countries. Git's distributed architecture, remote repository support, and branching and merging features make it easier for developers to collaborate regardless of their location. Developers can push and pull code changes from a remote repository accessible to all team members, which allows for real-time collaboration. Git's branching and merging features also enable developers to work on different features of a project simultaneously and merge their changes back into the main codebase without affecting other team members' work. Overall, Git's features make it an effective tool for distributed software development. The photo given in the lab is a really good visual I find.

# %% [markdown]
# ![git%20visual.jpg](attachment:git%20visual.jpg)

# %% [markdown]
# (question 13) Briefly describe the history of version control systems.
# Version control systems have a rich history, with the first predecessor being IEBUPDTE, which was developped in the early 1960s and used punched card to store data. In the 1970s, Bell Labs created SCCS, which was the first system to allow for the creation, editing, and tracking of changes to files. In the 1980s, Walter Tichy developed RCS, which introduced the concept of reverse deltas to track changes more eficiently. CVS, developed by Dick Grune in 1986, was a more modern example of version control, allowing multiple developers to work on a file at the same time. In 2000, Subversion (SVN) was created, which preserved many of the features of CVS while introducing a centralized version control system (CVCS). Currently, the most well-known distributed version control system (DVCS) is Git, created in 2005 by Linus Torvalds, which is fast, reliable, and has excellent branching capabilities. As repositories continue to grow, innovation in version control will likely continue.

# %% [markdown]
# [Summarized from this source](https://blog.tarynmcmillan.com/a-history-of-version-control)

# %% [markdown]
# (question 14) What are the most popular programming languages and why?
# I have a photo of the current top 5 programming laguages below. The first 2 languages are Python and C which is pretty self explanitory. Python is the most well rounded and easy to use language so it would attract the most people and C is the somewhat fundamental programming language which poeple have been using for years

# %% [markdown]
# ![top%20laguages-2.jpg](attachment:top%20laguages-2.jpg)

# %% [markdown]
# (question 15) C & Python are among the most popular programming languages. You are learning them in SENG 265. How cool is that for your software development career?
# Unbeleivably cool! I am extremely happy to be learning python especially because of the machine learning potential is has in the future. I find it tough to commit to learning a new language outside of school when you have a full course load so imhappy to be able to learn it in class and even get support when I have troubles. I aslo think C is a very important language to learn just because of the fact that it is connected to so many other languages and also the fact that it is a very old language.

# %% [markdown]
# (question 16) Describe the fundamental differences between C and Python.
# Instead I would like to visually represent the differences between both of the languages because I feel as though thats a better way to keep it in my bran and so that I can look back on this and see if im ever in question.

# %% [markdown]
# 1. Dynamic vs static typing: Python is dynamically typed, which means that the type of a variable can change at runtime, whereas C is statically typed, which means that the type of a variable must be declared at compile-time and cannot be changed at runtime.

# %%
#python
x = 5     
x = "hello" 

#C
int x = 5;     
x = "hello";  // Compilation error

# %% [markdown]
# 2. Interpreted vs compiled: Python is an interpreted language, which means that code is executed directly without compilation, whereas C is a compiled language, which means that code is first compiled into machine code before it can be executed.

# %%
#python
print("Hello, world!")

#C
#include <stdio.h>

int main() {
    printf("Hello, world!\n");
    return 0;
}

# %% [markdown]
# 3. Objects vs structures: Python is an object-oriented language where everything is an object, while C is a procedural language where data is typically organized into structures.

# %%
#python
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

person1 = Person("Alice", 25)

#C
struct Person {
    char *name;
    int age;
};

struct Person person1 = {"Alice", 25};

# %% [markdown]
# (question 17) How challenging were Assignment 1 and C for you?
# Assigment 1 was not to bad considering I cam from Java last semester. The only trouble that I had was working with pointers. Although the bill bird videos helped, I kept getting segmentation faults. Otherwise, I was able to teach myself C through YouTube primarily. The hardest part was the fact that in class we would go over C too late. For example the assignment woulf be due in 2 days and we were just starting pointers. Overall I would say the assignment was moderatly hard for someone who had no experince in C of even really working with strings. Another thing that was difficult in assignment 1 was figuring out how to work with files. (I had no idea what a csv file was before the assignment)

# %%
Core Dumped: Segmentation Falt!!!!   (trying to access something without permission)

# %% [markdown]
# (question 18) How challenging were Assignment 2 and Python 3 for you?
# I found python quite a bit easier to work with since it is so user friendly. The only thing that felt different was the indentation. I would honestly preffer working without indentation and brackets instead. I just like to be able to enclose certain functions so that they feel as though they are their own seperate "node" per say. I also dont like having to worry about indentation. When it comes to the assignment, it was quiet a bit easier than the first just because I was already familiar to working with files and printing specified outputs. The only new thing that came with the assignment was working with dataframes and creating plots. Since merging dataframes is so visual and I could print the colomns as I merged dataframes I had no trouble answering the questions that were asked.

# %%
import pandas as pd

data = {'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Emma', 'Frank'],
        'Age': [25, 30, 35, 40, 45, 50],
        'Gender': ['Female', 'Male', 'Male', 'Male', 'Female', 'Male'],
        'Country': ['USA', 'Canada', 'UK', 'Australia', 'USA', 'Canada'],
        'Salary': [50000, 75000, 90000, 110000, 65000, 85000]}
df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age  Gender    Country  Salary
# 0    Alice   25  Female        USA   50000
# 1      Bob   30    Male     Canada   75000
# 2  Charlie   35    Male         UK   90000
# 3    David   40    Male  Australia  110000
# 4     Emma   45  Female        USA   65000
# 5    Frank   50    Male     Canada   85000

# %% [markdown]
# I found it very convenient to visulaize the things I was doing on the assignemnt in jupyter notebooks. This givem me that chance to see operations such as:

# %%
import pandas as pd

data = {'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Emma', 'Frank'],
        'Age': [25, 30, 35, 40, 45, 50],
        'Gender': ['Female', 'Male', 'Male', 'Male', 'Female', 'Male'],
        'Country': ['USA', 'Canada', 'UK', 'Australia', 'USA', 'Canada'],
        'Salary': [50000, 75000, 90000, 110000, 65000, 85000]}
df = pd.DataFrame(data)
df = df.drop('Gender', axis=1)
print(df)
# Out:
#       Name  Age    Country  Salary
# 0    Alice   25        USA   50000
# 1      Bob   30     Canada   75000
# 2  Charlie   35         UK   90000
# 3    David   40  Australia  110000
# 4     Emma   45        USA   65000
# 5    Frank   50     Canada   85000

# %%
import pandas as pd

data = {'Name': ['Alice', 'Bob', 'Charlie', 'David', 'Emma', 'Frank'],
        'Age': [25, 30, 35, 40, 45, 50],
        'Gender': ['Female', 'Male', 'Male', 'Male', 'Female', 'Male'],
        'Country': ['USA', 'Canada', 'UK', 'Australia', 'USA', 'Canada'],
        'Salary': [50000, 75000, 90000, 110000, 65000, 85000]}
df = pd.DataFrame(data)

df['col_new'] = [10, 20, 30, 40, 50, 60]

df['col_new_2'] = df['Age'] * df['Salary']
print(df)
# Out:
#       Name  Age  Gender    Country  Salary  col_new  col_new_2
# 0    Alice   25  Female        USA   50000       10    1250000
# 1      Bob   30    Male     Canada   75000       20    2250000
# 2  Charlie   35    Male         UK   90000       30    3150000
# 3    David   40    Male  Australia  110000       40    4400000
# 4     Emma   45  Female        USA   65000       50    2925000
# 5    Frank   50    Male     Canada   85000       60    4250000

# %% [markdown]
# (question 20) What are your personal insights, aha moments, and epiphanies you experienced in the first part of the SENG 265 course?
# I feel as though there has always been a gap in my head between where i am now and what work is going to look like after school. After taking csc115 you dont really have any concept of medium scale projects or actual applications of programmimng. So far seng has really filled in this gap and I feel as though I have a stronger visual of what I will be doing after i graduate and maybe in some of my co-ops. After completing my first assignment I feel as though ive broken the barrier in front of my confusion.
